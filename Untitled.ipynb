# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

A = cv2.imread('original.jpg')
P = cv2.imread('fake.jpg')
plt.imshow(A)

# %%
a = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)
p = cv2.cvtColor(P, cv2.COLOR_BGR2GRAY)
plt.imshow(a)

# %%
a2tr = a[100:500,400 :800]
plt.imshow(a2tr)

# %%
print(a.shape)
a2_str =a[100:500,400 :800]
plt.imshow(a2_str)
# Out:
# (519, 1291)

# %%
hsvImageReal = cv2.cvtColor(A, cv2.COLOR_BGR2HSV)
hsvImageFake = cv2.cvtColor(P, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsvImageReal)

# %%
plt.imshow(hsvImageFake)

# %%
croppedImageReal = hsvImageReal[100:600,400 :800]
x=plt.imshow(croppedImageReal)

# %%
croppedImageFake = hsvImageFake[20:200, 50:200]
y=plt.imshow(croppedImageFake)

# %%
import PIL
image = PIL.Image.open('outputfake.png')
image2 = PIL.Image.open('outputreal.png')

# %%
if image==image2:
    print('The Given Currency is Real')
else:
    print('The currency is fake')
# Out:
# The currency is fake
